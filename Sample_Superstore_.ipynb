# %%
# import all Library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Read the Dataset
df = pd.read_csv("/content/drive/MyDrive/Sample - Superstore.xls", encoding="cp1252")

# %%
df

# %%
# first 5 row of the dataset
df.head()

# %%
#Sample

df.sample(5)

# %%
# Preview of the Dataset
df.info()

# %%
# Mathematical Summary
df.describe()

# %%
# Check all null Value
df.isnull().sum()

# %%
# Check all Duplicated Value
df.duplicated().sum()

# %%
# Check the No. of Unique Value
df.nunique()

# %%
# Sort the Order Date
df.sort_values(['Order Date'],ascending=True,inplace=True)

# %%
# Reset the index
df.reset_index(inplace=True)

# %%
df.head()

# %% [markdown]
# # Filtering Data

# %% [markdown]
# # Grouping Data

# %% [markdown]
# # Data_visualization

# %%
# See the Sales of Category
plt.figure(figsize=(10,5))
with sns.axes_style('darkgrid'):
  sns.barplot(data=df,x='Category',y='Sales',color="#FA8FA1",width=0.5)
  plt.title("Sales Vs Category ")
  plt.show()

# %%
x=df['Region'].value_counts()
y=df['Region'].value_counts().index
ex=[0,0,0,0.1]
plt.pie(x,labels=y,shadow=True,explode=ex,radius=1.2,colors=['#04FBE7','#30FC8C','#FB0429','#FCBF30'],autopct='%0.2f%%')
plt.title('Region',fontsize=15)
plt.show()

# %%
sns.swarmplot(data=df,y='Sales',x='Discount',color='r')
plt.title('Sales VS Discount',fontsize=15)
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 98.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 75.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 71.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 98.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 90.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 48.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 85.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 18.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 77.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 95.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 95.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 95.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df['Sales'].max()

# %%
plt.figure(figsize=(15,5))
with sns.axes_style('darkgrid'):
  sns.barplot(data=df,y='Sales',x='State',palette="viridis",orient='h',hue='Ship Mode',width=0.8)
  plt.title("Sales Vs State",fontsize=15)
  plt.show()

# %%
plt.figure(figsize=(10,5))
with sns.axes_style('whitegrid'):
  sns.kdeplot( data=df,
    x='Sales',
    fill=False)
  plt.xlim(-1000,5000)
  plt.title('Sales',fontsize=15)

  plt.show()

# %%
plt.figure(figsize=(10,5))
with sns.axes_style('whitegrid'):
  sns.kdeplot( data=df,
    x='Sales',
    hue='Segment',
    fill=False)
  plt.xlim(-1000,5000)
  plt.title('Sales VS Segement',fontsize=15)
  plt.show()

# %%
plt.figure(figsize=(10,5))
with sns.axes_style('darkgrid'):
  sns.barplot(data=df,x='Category',y='Sales',palette="viridis",width=0.6,hue='Segment')
  plt.title("Sales Vs Category",fontsize=15)
  plt.show()

# %%
# See the Sales of Category
plt.figure(figsize=(10,5))
with sns.axes_style('darkgrid'):
  sns.barplot(data=df,x='Category',y='Sales',palette='rocket',hue='Ship Mode')
  plt.title("Sales Vs Category",fontsize=15)
  plt.show()

# %%
ex=[0,0,0.1]

plt.pie(df['Segment'].value_counts(),labels=df['Segment'].value_counts().index,colors=['#F5C894','#9DFF5C','#FF8AB9'],autopct='%0.2f%%',
shadow=True,explode=ex,radius=1.2,startangle=20)

plt.title('Segment',fontsize=15)
plt.show()

# %%
# See the Sales of Sub Category
plt.figure(figsize=(10,5))
with sns.axes_style('darkgrid'):
  sns.barplot(data=df,x='Sub-Category',y='Sales',color='#EFFF2E',width=1)
  plt.title("Sales Vs Sub-Category",fontsize=15)

  plt.xticks(rotation=63)
  plt.show()

# %%
sns.relplot(data=df,x='Sales',y='Profit',kind='scatter',color='r')
plt.title('Sales VS Profit',fontsize=15)
plt.grid()
plt.show()

# %%
# See the Sales of sub-Category
plt.figure(figsize=(50,7))
with sns.axes_style('darkgrid'):
  sns.catplot(data=df,x='Sub-Category',y='Sales',palette="Set2",hue='Category',kind='bar')
  plt.title("Sales Vs Sub-Category")
  plt.xticks(rotation=55)
  plt.show()

# %%
plt.figure(figsize=(15,5))
with sns.axes_style('darkgrid'):
  sns.barplot(data=df,y='Quantity',x='Category',palette="crest",orient='v',hue='Region',width=0.8)
  plt.title("Quantity Vs Category",fontsize=15)
  plt.legend(loc=2)
  plt.show()

# %%
plt.figure(figsize=(15,5))
with sns.axes_style('darkgrid'):
  sns.barplot(data=df,y='Quantity',x='Sub-Category',palette="flame",orient='v',hue='Category',width=0.8)
  plt.title("Quantity Vs Sub-Category",fontsize=15)
  plt.legend(loc=2)
  plt.show()

# %%
sns.swarmplot(data=df,y='Sales',x='Quantity',color='y',marker='o')
plt.title('Sales VS Quantity',fontsize=15)
plt.grid()
plt.show()
